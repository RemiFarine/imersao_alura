# %% [markdown]
# <a href="https://colab.research.google.com/github/RemiFarine/imersao_alura/blob/main/Dados/R%C3%A9mi_imers%C3%A3o_Alura_aula_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
url = "https://gist.githubusercontent.com/tgcsantos/3bdb29eba6ce391e90df2b72205ba891/raw/22fa920e80c9fa209a9fccc8b52d74cc95d1599b/dados_imoveis.csv"
dados = pd.read_csv(url)

# %%
dados.head(13)
# Out:
#                                Rua              Bairro     Cidade  Metragem  \
# 0            Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1   Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                  Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                              NaN      Jardim Morumbi  São Paulo       310
# 4         Rua Tobias Barreto, 195                Mooca  São Paulo       100
# 5                  Rua Graham Bell         Santo Amaro  São Paulo       440
# 6         Rua Francisco Paulo, 31    Cidade Mãe do Céu  São Paulo       145
# 7      Rua Guilherme Valente, 150     Jardim Vergueiro  São Paulo       150
# 8          Rua Sagrada Família, 8       Jardim Benfica  São Paulo        48
# 9                       Rua Tapaji         Vila Alpina  São Paulo       114
# 10   Rua Vigário João Álvares, 66       Vila Monumento  São Paulo       261
# ...

# %%
dados.sample(13
    )
# Out:
#                           Rua            Bairro     Cidade  Metragem  Quartos  \
# 1611                      NaN    Jardim Guedala  São Paulo       496        4
# 7442                Rua Viena            Sacomã  São Paulo       132        3
# 5864           Avenida Cupecê  Jardim Prudência  São Paulo       167        2
# 4033  Rua Nabih Assad Abdalla      Vila Morumbi  São Paulo       307        3
# 7440               Rua Acuruá       Vila Romana  São Paulo       295        4
# 5182      Rua da Constituinte          Ipiranga  São Paulo       160        3
# 8664  Avenida João José Gomes      Vila Antônio  São Paulo       110        2
# 6437                      NaN    Jardim Colombo  São Paulo       232        3
# 1668             Rua Antilhas    Jardim América  São Paulo       600        5
# 5713                      NaN  Jardim Ernestina  São Paulo       200        3
# 4661  Rua General Eloy Alfaro      Vila Mariana  São Paulo       120        2
# ...

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10008 entries, 0 to 10007
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Rua        6574 non-null   object
#  1   Bairro     9996 non-null   object
#  2   Cidade     10008 non-null  object
#  3   Metragem   10008 non-null  int64
#  4   Quartos    10008 non-null  int64
#  5   Banheiros  10008 non-null  int64
#  6   Vagas      10008 non-null  int64
#  7   Valor      10008 non-null  object
# dtypes: int64(4), object(4)
# memory usage: 625.6+ KB

# %%
dados["Bairro"][13]
# Out:
# 'Jardim Prudência'

# %%
dados["Rua"][13]
# Out:
# 'Rua Antônio Pereira Mendes, 98 '

# %%
dados.head(1)
# Out:
#                      Rua             Bairro     Cidade  Metragem  Quartos  \
# 0  Avenida Itacira, 255   Planalto Paulista  São Paulo      1000        4
#
#    Banheiros  Vagas         Valor
# 0          8      6  R$ 7.000.000

# %%
dados.Metragem.mean()
# Out:
# 442.30065947242207

# %%
dados["Metragem"][1]
# Out:
# 496

# %%
dados['Bairro'] == 'Vila Mariana'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10003    False
# 10004    False
# 10005    False
# 10006    False
# 10007    False
# Name: Bairro, Length: 10008, dtype: bool

# %%
sum((dados["Bairro"] == "Vila Mariana"))
# Out:
# 184

# %%
tem_imoveis_vila = (dados["Bairro"] == "Vila Mariana")
tem_imoveis_vila
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10003    False
# 10004    False
# 10005    False
# 10006    False
# 10007    False
# Name: Bairro, Length: 10008, dtype: bool

# %%
imoveis_vila_mariana = dados[tem_imoveis_vila]
imoveis_vila_mariana
# Out:
#                                Rua        Bairro     Cidade  Metragem  \
# 100               Rua Pero Correia  Vila Mariana  São Paulo       250
# 120   Praça Doutor Carvalho Franco  Vila Mariana  São Paulo       250
# 155     Rua Professor João Marinho  Vila Mariana  São Paulo       170
# 160                            NaN  Vila Mariana  São Paulo       228
# 334         Rua Pero Correia, 892   Vila Mariana  São Paulo       350
# ...                            ...           ...        ...       ...
# 9645               Rua Sousa Ramos  Vila Mariana  São Paulo       285
# 9701             Rua Benito Juarez  Vila Mariana  São Paulo       171
# 9737             Rua Benito Juarez  Vila Mariana  São Paulo       171
# 9807                           NaN  Vila Mariana  São Paulo       275
# 9852              Rua França Pinto  Vila Mariana  São Paulo       280
#
#       Quartos  Banheiros  Vagas         Valor
# 100         3          3      1  R$ 1.350.000
# ...

# %%
imoveis_vila_mariana["Metragem"].mean()
# Out:
# 233.6195652173913

# %%
dados["Bairro"].value_counts()
# Out:
# Alto de Pinheiros     409
# Jardim Guedala        403
# Jardim Paulista       309
# Brooklin Paulista     247
# Jardim Europa         240
#                      ...
# Jardim das Imbuias      1
# Vila Represa            1
# Vila Nancy              1
# Sítio Represa           1
# Vila Invernada          1
# Name: Bairro, Length: 701, dtype: int64

# %%
n_imoveis_bairro = dados["Bairro"].value_counts()
n_imoveis_bairro.head(10).plot.bar()

# %% [markdown]
# Desafios:
#
# 1 - Realizar a média da metragem para cara um dos bairros (Paulo)
#
# 2 - 2 formas de selecionar os dados por bairro (consultar os métodos na documentação do pandas) (Thiago)
#
# 3 - Explorar alguns gráficos na documentação e aplicar nas demais colunas do DF, tentar colocar alguma conclusão (Thiago)
#
# 4 - Pegar outros estatísticas dos dados, média, mediana, mim, max (Vivi)
#
# 5 - Descobrir quais são os bairros que não tem nome de Rua. (Vivi)

# %% [markdown]
# ### Desafio 1
# ##### Realizar a média da metragem para cara um dos bairros.

# %%
dados.groupby('Bairro')['Metragem'].mean()
# Out:
# Bairro
# Aclimação            253.056818
# Alto da Boa Vista    418.875000
# Alto da Lapa         294.337209
# Alto da Mooca        270.050000
# Alto de Pinheiros    433.444988
#                         ...
# Vila Água Funda      152.200000
# Água Branca          191.000000
# Água Fria            165.416667
# Água Funda           139.000000
# Água Rasa            340.250000
# Name: Metragem, Length: 701, dtype: float64

# %% [markdown]
# ### Desafio 2
# ##### Apresentar 2 formas de selecionar os dados por bairro.

# %%
dados["Bairro"]
# Out:
# 0         Planalto Paulista
# 1        Jardim dos Estados
# 2           Jardim Reimberg
# 3            Jardim Morumbi
# 4                     Mooca
#                 ...
# 10003            Vila Sofia
# 10004       Bosque da Saúde
# 10005         Vila da Saúde
# 10006         Vila Oratório
# 10007           Vila Alpina
# Name: Bairro, Length: 10008, dtype: object

# %%
dados[dados['Bairro']== 'Morumbi']
# Out:
#                                        Rua   Bairro     Cidade  Metragem  \
# 171                    Rua Luís Dib Zogaib  Morumbi  São Paulo       443
# 191                                    NaN  Morumbi  São Paulo      1800
# 213                     Rua Emílio Pedutti  Morumbi  São Paulo       546
# 343   Avenida Comendador Adibo Ares, 1230   Morumbi  São Paulo       686
# 377                                    NaN  Morumbi  São Paulo       566
# ...                                    ...      ...        ...       ...
# 9486            Rua Almirante Soares Dutra  Morumbi  São Paulo       499
# 9527         Avenida Comendador Adibo Ares  Morumbi  São Paulo      1000
# 9555            Rua Almirante Soares Dutra  Morumbi  São Paulo       558
# 9628            Rua Almirante Soares Dutra  Morumbi  São Paulo       504
# 9757       Rua General Euclides Figueiredo  Morumbi  São Paulo       460
#
#       Quartos  Banheiros  Vagas                                  Valor
# ...

# %% [markdown]
# ### Desafio 3
# ##### Explorar alguns gráficos na documentação e aplicar nas demais colunas do DF, tentar colocar alguma conclusão.

# %%
dados[['Bairro','Quartos','Banheiros']].head(4).groupby('Bairro').mean().plot.barh()

# %%
dados[['Bairro','Metragem']].head(4).groupby('Bairro').mean().plot.line()

# %% [markdown]
# ### Desafio 4
# ##### Pegar outros estatísticas dos dados, média, mediana, mim, max.

# %%
dados.describe()
# Out:
#             Metragem       Quartos     Banheiros         Vagas
# count   10008.000000  10008.000000  10008.000000  10008.000000
# mean      442.300659      3.483114      3.879097      4.097222
# std      7515.379389      1.064200      1.988467      2.824014
# min        10.000000      1.000000      1.000000      1.000000
# 25%       173.000000      3.000000      2.000000      2.000000
# 50%       290.000000      3.000000      4.000000      4.000000
# 75%       460.250000      4.000000      5.000000      5.000000
# max    750000.000000     16.000000     40.000000     50.000000

# %% [markdown]
# ### Desafio 5
# ##### Descobrir quais são os bairros que não tem nome de Rua.

# %%
dados[dados['Rua'].isna()].groupby('Bairro')['Bairro'].unique().values
# Out:
# array([array(['Aclimação'], dtype=object),
#        array(['Alto da Boa Vista'], dtype=object),
#        array(['Alto da Lapa'], dtype=object),
#        array(['Alto da Mooca'], dtype=object),
#        array(['Alto de Pinheiros'], dtype=object),
#        array(['Aricanduva'], dtype=object),
#        array(['Barra Funda'], dtype=object),
#        array(['Bela Aliança'], dtype=object),
#        array(['Belenzinho'], dtype=object),
#        array(['Boaçava'], dtype=object),
#        array(['Bosque da Saúde'], dtype=object),
#        array(['Brasilândia'], dtype=object),
#        array(['Brooklin'], dtype=object),
#        array(['Brooklin Novo'], dtype=object),
#        array(['Brooklin Paulista'], dtype=object),
#        array(['Brás'], dtype=object),
#        array(['Burgo Paulista'], dtype=object),
#        array(['Butantã'], dtype=object), array(['Cambuci'], dtype=object),
#        array(['Campininha'], dtype=object),
#        array(['Campo Belo'], dtype=object),
# ...
